# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !python task3/train.py
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 143MB/s]
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#
# ======================================================================
# SOURCE-ONLY ERM BASELINE
# photo           | Accuracy: 0.9701 | Macro-F1: 0.9645
# art_painting    | Accuracy: 0.8878 | Macro-F1: 0.8870
# cartoon         | Accuracy: 0.9403 | Macro-F1: 0.9480
#
# Mean             | Accuracy: 0.9327 | Macro-F1: 0.9332
# Worst-domain     | Accuracy: 0.8878 | Macro-F1: 0.8870
#
# ======================================================================
# PART 2 - DAN-DG
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#
# DAN-DG | Epoch 1/30
#   Train Loss: 0.2607 | ERM: 0.4841 | MMD: -0.2234
#   Mean Source Macro-F1: 0.9261
#   photo: Acc=0.9731, F1=0.9699
#   art_painting: Acc=0.9049, F1=0.9039
#   cartoon: Acc=0.9083, F1=0.9045
#   Saved best DAN-DG checkpoint.
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)

# %%
# !find /content/drive/MyDrive -maxdepth 3 -type d -iname "PACS"

# %%
# %cd /content/drive/MyDrive
# !python task3/train.py
# Out:
# /content/drive/MyDrive
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 193MB/s]
#
# ======================================================================
# SOURCE-ONLY ERM BASELINE
# photo           | Accuracy: 0.9701 | Macro-F1: 0.9645
# art_painting    | Accuracy: 0.8878 | Macro-F1: 0.8870
# cartoon         | Accuracy: 0.9403 | Macro-F1: 0.9480
#
# Mean             | Accuracy: 0.9327 | Macro-F1: 0.9332
# Worst-domain     | Accuracy: 0.8878 | Macro-F1: 0.8870
#
# ======================================================================
# PART 2 - DAN-DG
# ======================================================================
#
# DAN-DG | Epoch 1/30
#   Train Loss: 0.2600 | ERM: 0.4835 | MMD: -0.2236
#   Mean Source Macro-F1: 0.9192
#   photo: Acc=0.9671, F1=0.9617
#   art_painting: Acc=0.9049, F1=0.9051
#   cartoon: Acc=0.8977, F1=0.8908
#   Saved best DAN-DG checkpoint.
#
# DAN-DG | Epoch 2/30
#   Train Loss: -0.0213 | ERM: 0.2033 | MMD: -0.2245
#   Mean Source Macro-F1: 0.9287
#   photo: Acc=0.9760, F1=0.9718
#   art_painting: Acc=0.8854, F1=0.8895
#   cartoon: Acc=0.9190, F1=0.9249
#   Saved best DAN-DG checkpoint.
#
# DAN-DG | Epoch 3/30
#   Train Loss: -0.0736 | ERM: 0.1504 | MMD: -0.2240
#   Mean Source Macro-F1: 0.9318
#   photo: Acc=0.9671, F1=0.9638
#   art_painting: Acc=0.9049, F1=0.9047
#   cartoon: Acc=0.9168, F1=0.9269
#   Saved best DAN-DG checkpoint.
#
# DAN-DG | Epoch 4/30
#   Train Loss: -0.0991 | ERM: 0.1246 | MMD: -0.2237
#   Mean Source Macro-F1: 0.9098
#   photo: Acc=0.9731, F1=0.9687
#   art_painting: Acc=0.8902, F1=0.8913
#   cartoon: Acc=0.8721, F1=0.8694
#   No improvement (1/5)
#
# DAN-DG | Epoch 5/30
#   Train Loss: -0.1233 | ERM: 0.1004 | MMD: -0.2237
#   Mean Source Macro-F1: 0.9331
#   photo: Acc=0.9701, F1=0.9666
#   art_painting: Acc=0.9073, F1=0.9054
#   cartoon: Acc=0.9232, F1=0.9271
#   Saved best DAN-DG checkpoint.
#
# DAN-DG | Epoch 6/30
#   Train Loss: -0.1455 | ERM: 0.0784 | MMD: -0.2239
#   Mean Source Macro-F1: 0.9338
#   photo: Acc=0.9850, F1=0.9819
#   art_painting: Acc=0.8805, F1=0.8830
#   cartoon: Acc=0.9318, F1=0.9365
#   Saved best DAN-DG checkpoint.
#
# DAN-DG | Epoch 7/30
#   Train Loss: -0.1564 | ERM: 0.0694 | MMD: -0.2259
#   Mean Source Macro-F1: 0.9343
#   photo: Acc=0.9731, F1=0.9701
#   art_painting: Acc=0.9024, F1=0.9036
#   cartoon: Acc=0.9254, F1=0.9291
#   Saved best DAN-DG checkpoint.
#
# DAN-DG | Epoch 8/30
#   Train Loss: -0.1538 | ERM: 0.0699 | MMD: -0.2237
#   Mean Source Macro-F1: 0.9355
#   photo: Acc=0.9790, F1=0.9756
#   art_painting: Acc=0.8878, F1=0.8848
#   cartoon: Acc=0.9403, F1=0.9460
#   Saved best DAN-DG checkpoint.
#
# DAN-DG | Epoch 9/30
#   Train Loss: -0.1608 | ERM: 0.0637 | MMD: -0.2245
#   Mean Source Macro-F1: 0.9270
#   photo: Acc=0.9701, F1=0.9656
#   art_painting: Acc=0.8829, F1=0.8874
#   cartoon: Acc=0.9275, F1=0.9281
#   No improvement (1/5)
#
# DAN-DG | Epoch 10/30
#   Train Loss: -0.1659 | ERM: 0.0589 | MMD: -0.2248
#   Mean Source Macro-F1: 0.9241
#   photo: Acc=0.9760, F1=0.9728
#   art_painting: Acc=0.8878, F1=0.8836
#   cartoon: Acc=0.9126, F1=0.9160
#   No improvement (2/5)
#
# DAN-DG | Epoch 11/30
#   Train Loss: -0.1601 | ERM: 0.0620 | MMD: -0.2221
#   Mean Source Macro-F1: 0.9105
#   photo: Acc=0.9611, F1=0.9543
#   art_painting: Acc=0.8683, F1=0.8644
#   cartoon: Acc=0.9041, F1=0.9127
#   No improvement (3/5)
#
# DAN-DG | Epoch 12/30
#   Train Loss: -0.1831 | ERM: 0.0441 | MMD: -0.2271
#   Mean Source Macro-F1: 0.9310
#   photo: Acc=0.9701, F1=0.9654
#   art_painting: Acc=0.8878, F1=0.8860
#   cartoon: Acc=0.9360, F1=0.9418
#   No improvement (4/5)
#
# DAN-DG | Epoch 13/30
#   Train Loss: -0.1879 | ERM: 0.0361 | MMD: -0.2240
#   Mean Source Macro-F1: 0.9207
#   photo: Acc=0.9701, F1=0.9650
#   art_painting: Acc=0.8878, F1=0.8826
#   cartoon: Acc=0.9062, F1=0.9146
#   No improvement (5/5)
#
# Early stopping at epoch 13.
#
# ======================================================================
# DAN-DG TRAINING COMPLETE
# ======================================================================
# Best epoch: 8
# Best mean source Macro-F1: 0.9355
# Checkpoint: /content/drive/MyDrive/task3/results/dan_dg_best.pth

# %%
# !find /content/drive/MyDrive -maxdepth 2 -type d | head -100
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/task3
# /content/drive/MyDrive/task3/evaluation
# /content/drive/MyDrive/task3/selection
# /content/drive/MyDrive/task3/models
# /content/drive/MyDrive/task3/configs
# /content/drive/MyDrive/task3/methods
# /content/drive/MyDrive/shared
# /content/drive/MyDrive/shared/__pycache__
# /content/drive/MyDrive/shared/splits

# %%
# !find /content -maxdepth 4 -type d -iname "PACS" 2>/dev/null

# %%
# !find /content -maxdepth 5 -type f -name "063_0024.jpg" 2>/dev/null

# %%
from pathlib import Path

print(Path("/content/drive/MyDrive/PACS/PACS/photo").exists())
print(Path("/content/drive/MyDrive/shared/splits/pacs_sketch_seed6304.json").exists())
# Out:
# True
# True

# %%
# %cd /content/drive/MyDrive

# !python -m task2.train --config task2/configs/source_only.yaml
# Out:
# /content/drive/MyDrive
# Device: cuda
# photo: 1336 train, 334 validation
# art_painting: 1638 train, 410 validation
# cartoon: 1875 train, 469 validation
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 130MB/s]
#
# Epoch 01 | Loss: 0.5251 | Mean Source Macro-F1: 0.8698
#   photo         | Acc: 0.9461 | Macro-F1: 0.9342
#   art_painting  | Acc: 0.7780 | Macro-F1: 0.7832
#   cartoon       | Acc: 0.8785 | Macro-F1: 0.8920
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/source_only_erm_best.pth
#
# Epoch 02 | Loss: 0.2580 | Mean Source Macro-F1: 0.9196
#   photo         | Acc: 0.9551 | Macro-F1: 0.9455
#   art_painting  | Acc: 0.8878 | Macro-F1: 0.8846
#   cartoon       | Acc: 0.9190 | Macro-F1: 0.9286
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/source_only_erm_best.pth
#
# Epoch 03 | Loss: 0.1729 | Mean Source Macro-F1: 0.9223
#   photo         | Acc: 0.9671 | Macro-F1: 0.9608
#   art_painting  | Acc: 0.8780 | Macro-F1: 0.8793
#   cartoon       | Acc: 0.9211 | Macro-F1: 0.9269
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/source_only_erm_best.pth
#
# Epoch 04 | Loss: 0.1540 | Mean Source Macro-F1: 0.9332
#   photo         | Acc: 0.9701 | Macro-F1: 0.9645
#   art_painting  | Acc: 0.8878 | Macro-F1: 0.8870
#   cartoon       | Acc: 0.9403 | Macro-F1: 0.9480
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/source_only_erm_best.pth
#
# Epoch 05 | Loss: 0.1167 | Mean Source Macro-F1: 0.9065
#   photo         | Acc: 0.9551 | Macro-F1: 0.9471
#   art_painting  | Acc: 0.8341 | Macro-F1: 0.8464
#   cartoon       | Acc: 0.9168 | Macro-F1: 0.9261
#
# Epoch 06 | Loss: 0.1099 | Mean Source Macro-F1: 0.9224
#   photo         | Acc: 0.9581 | Macro-F1: 0.9534
#   art_painting  | Acc: 0.9049 | Macro-F1: 0.8905
#   cartoon       | Acc: 0.9168 | Macro-F1: 0.9234
#
# Epoch 07 | Loss: 0.0686 | Mean Source Macro-F1: 0.9263
#   photo         | Acc: 0.9581 | Macro-F1: 0.9489
#   art_painting  | Acc: 0.9098 | Macro-F1: 0.9108
#   cartoon       | Acc: 0.9147 | Macro-F1: 0.9193
#
# Epoch 08 | Loss: 0.0745 | Mean Source Macro-F1: 0.9070
#   photo         | Acc: 0.9551 | Macro-F1: 0.9477
#   art_painting  | Acc: 0.8366 | Macro-F1: 0.8463
#   cartoon       | Acc: 0.9190 | Macro-F1: 0.9271
#
# Epoch 09 | Loss: 0.0956 | Mean Source Macro-F1: 0.9183
#   photo         | Acc: 0.9611 | Macro-F1: 0.9551
#   art_painting  | Acc: 0.8512 | Macro-F1: 0.8520
#   cartoon       | Acc: 0.9403 | Macro-F1: 0.9479
#
# Early stopping at epoch 9.
#
# Training complete.
# Best mean source validation Macro-F1: 0.9331710366486771
# Checkpoint: /content/drive/MyDrive/task2/results/source_only_erm_best.pth

# %%
# %cd /content/drive/MyDrive/task2
# %cd /content/drive/MyDrive/shared
# Out:
# /content/drive/MyDrive/task2
# /content/drive/MyDrive/shared

# %%
# !touch shared/__init__.py
# !touch task2/__init__.py

# %%
from pathlib import Path

files = list(Path("/root/.cache/huggingface").rglob("PACS.zip"))
print(files)
# Out:
# [PosixPath('/root/.cache/huggingface/hub/datasets--Azeez577--PACS/snapshots/fb1ee820df83b4e9957251d9f6973eb6d424c494/PACS.zip')]

# %%
# %cd /content/drive/MyDrive

# !python -m shared.pacs_protocol \
    --data_root "/content/drive/MyDrive/PACS/PACS" \
    --output "shared/splits/pacs_sketch_seed6304.json"
# Out:
# /content/drive/MyDrive
# photo: total=1670, train=1336, val=334
# art_painting: total=2048, train=1638, val=410
# cartoon: total=2344, train=1875, val=469
#
# Saved split file to: shared/splits/pacs_sketch_seed6304.json

# %%
# %cd /content/drive/MyDrive
# !cat task2/configs/dan.yaml
# Out:
# /content/drive/MyDrive
# seed: 6304
#
# data:
#   root: "/content/drive/MyDrive/PACS/PACS"
#   split_file: "/content/drive/MyDrive/shared/splits/pacs_sketch_seed6304.json"
#
# sources:
#   - photo
#   - art_painting
#   - cartoon
#
# target: sketch
#
# model:
#   num_classes: 7
#   backbone: resnet18
#   weights: IMAGENET1K_V1
#
# training:
#   epochs: 30
#   patience: 5
#   batch_size_per_source: 8
#   target_batch_size: 24
#   learning_rate: 0.0001
#   weight_decay: 0.0001
#
# adaptation:
#   lambda: 1.0
#
# method: dan

# %%
# %cd /content/drive/MyDrive
# !python -m task2.train --config task2/configs/dan.yaml
# Out:
# /content/drive/MyDrive
# Device: cuda
# Method: dan
# photo: 1336 train, 334 validation
# art_painting: 1638 train, 410 validation
# cartoon: 1875 train, 469 validation
#
# Epoch 01 | Total Loss: 0.5083 | Cls: 0.4541 | MMD: 0.0541 | Mean Source Macro-F1: 0.9138
#   photo         | Acc: 0.9551 | Macro-F1: 0.9498
#   art_painting  | Acc: 0.8561 | Macro-F1: 0.8533
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9381
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_best.pth
#
# Epoch 02 | Total Loss: 0.2272 | Cls: 0.1988 | MMD: 0.0284 | Mean Source Macro-F1: 0.8966
#   photo         | Acc: 0.9461 | Macro-F1: 0.9363
#   art_painting  | Acc: 0.8707 | Macro-F1: 0.8587
#   cartoon       | Acc: 0.8934 | Macro-F1: 0.8947
#
# Epoch 03 | Total Loss: 0.1820 | Cls: 0.1591 | MMD: 0.0229 | Mean Source Macro-F1: 0.9264
#   photo         | Acc: 0.9641 | Macro-F1: 0.9563
#   art_painting  | Acc: 0.8854 | Macro-F1: 0.8865
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9364
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_best.pth
#
# Epoch 04 | Total Loss: 0.1219 | Cls: 0.1106 | MMD: 0.0113 | Mean Source Macro-F1: 0.9088
#   photo         | Acc: 0.9251 | Macro-F1: 0.9092
#   art_painting  | Acc: 0.8951 | Macro-F1: 0.8911
#   cartoon       | Acc: 0.9190 | Macro-F1: 0.9261
#
# Epoch 05 | Total Loss: 0.1098 | Cls: 0.0956 | MMD: 0.0143 | Mean Source Macro-F1: 0.9171
#   photo         | Acc: 0.9551 | Macro-F1: 0.9459
#   art_painting  | Acc: 0.8463 | Macro-F1: 0.8516
#   cartoon       | Acc: 0.9488 | Macro-F1: 0.9537
#
# Epoch 06 | Total Loss: 0.0808 | Cls: 0.0703 | MMD: 0.0105 | Mean Source Macro-F1: 0.9431
#   photo         | Acc: 0.9760 | Macro-F1: 0.9723
#   art_painting  | Acc: 0.9073 | Macro-F1: 0.9101
#   cartoon       | Acc: 0.9424 | Macro-F1: 0.9469
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_best.pth
#
# Epoch 07 | Total Loss: 0.0779 | Cls: 0.0713 | MMD: 0.0066 | Mean Source Macro-F1: 0.9189
#   photo         | Acc: 0.9641 | Macro-F1: 0.9586
#   art_painting  | Acc: 0.8561 | Macro-F1: 0.8573
#   cartoon       | Acc: 0.9403 | Macro-F1: 0.9408
#
# Epoch 08 | Total Loss: 0.0831 | Cls: 0.0745 | MMD: 0.0086 | Mean Source Macro-F1: 0.9193
#   photo         | Acc: 0.9461 | Macro-F1: 0.9369
#   art_painting  | Acc: 0.8756 | Macro-F1: 0.8837
#   cartoon       | Acc: 0.9339 | Macro-F1: 0.9374
#
# Epoch 09 | Total Loss: 0.0609 | Cls: 0.0521 | MMD: 0.0088 | Mean Source Macro-F1: 0.9100
#   photo         | Acc: 0.9491 | Macro-F1: 0.9414
#   art_painting  | Acc: 0.8634 | Macro-F1: 0.8624
#   cartoon       | Acc: 0.9190 | Macro-F1: 0.9260
#
# Epoch 10 | Total Loss: 0.0727 | Cls: 0.0666 | MMD: 0.0061 | Mean Source Macro-F1: 0.9326
#   photo         | Acc: 0.9551 | Macro-F1: 0.9467
#   art_painting  | Acc: 0.8976 | Macro-F1: 0.8980
#   cartoon       | Acc: 0.9488 | Macro-F1: 0.9531
#
# Epoch 11 | Total Loss: 0.0620 | Cls: 0.0547 | MMD: 0.0073 | Mean Source Macro-F1: 0.9223
#   photo         | Acc: 0.9581 | Macro-F1: 0.9503
#   art_painting  | Acc: 0.8756 | Macro-F1: 0.8670
#   cartoon       | Acc: 0.9467 | Macro-F1: 0.9498
#
# Early stopping at epoch 11.
#
# Training complete.
# Best mean source validation Macro-F1: 0.943114996056044
# Checkpoint: /content/drive/MyDrive/task2/results/dan_best.pth

# %%
# %cd /content/drive/MyDrive

# !python -m task2.train --config task2/configs/dann.yaml
# Out:
# /content/drive/MyDrive
# Device: cuda
# Method: dann
# photo: 1336 train, 334 validation
# art_painting: 1638 train, 410 validation
# cartoon: 1875 train, 469 validation
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 136MB/s]
#
# Epoch 01 | Total Loss: 820.8470 | Cls: 48.2832 | Domain: 772.5638 | Alpha: 0.0826 | Mean Source Macro-F1: 0.0585
#   photo         | Acc: 0.2575 | Macro-F1: 0.0586
#   art_painting  | Acc: 0.2195 | Macro-F1: 0.0518
#   cartoon       | Acc: 0.1727 | Macro-F1: 0.0650
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dann_best.pth
#
# Epoch 02 | Total Loss: 118.9719 | Cls: 21.6838 | Domain: 97.2881 | Alpha: 0.2441 | Mean Source Macro-F1: 0.0351
#   photo         | Acc: 0.1198 | Macro-F1: 0.0306
#   art_painting  | Acc: 0.1000 | Macro-F1: 0.0286
#   cartoon       | Acc: 0.1407 | Macro-F1: 0.0461
#
# Epoch 03 | Total Loss: 623.8127 | Cls: 184.2827 | Domain: 439.5300 | Alpha: 0.3931 | Mean Source Macro-F1: 0.0523
#   photo         | Acc: 0.2575 | Macro-F1: 0.0585
#   art_painting  | Acc: 0.2195 | Macro-F1: 0.0514
#   cartoon       | Acc: 0.1748 | Macro-F1: 0.0470
#
# Epoch 04 | Total Loss: 6.6099 | Cls: 3.0779 | Domain: 3.5320 | Alpha: 0.5240 | Mean Source Macro-F1: 0.0507
#   photo         | Acc: 0.2575 | Macro-F1: 0.0585
#   art_painting  | Acc: 0.2195 | Macro-F1: 0.0514
#   cartoon       | Acc: 0.1727 | Macro-F1: 0.0422
#
# Epoch 05 | Total Loss: 6.8045 | Cls: 3.4194 | Domain: 3.3851 | Alpha: 0.6341 | Mean Source Macro-F1: 0.0382
#   photo         | Acc: 0.1138 | Macro-F1: 0.0292
#   art_painting  | Acc: 0.1854 | Macro-F1: 0.0447
#   cartoon       | Acc: 0.1663 | Macro-F1: 0.0407
#
# Epoch 06 | Total Loss: 144306842.3094 | Cls: 65696836.2353 | Domain: 78610006.3684 | Alpha: 0.7234 | Mean Source Macro-F1: 0.0508
#   photo         | Acc: 0.1228 | Macro-F1: 0.0510
#   art_painting  | Acc: 0.1293 | Macro-F1: 0.0437
#   cartoon       | Acc: 0.1855 | Macro-F1: 0.0577
#
# Early stopping at epoch 6.
#
# Training complete.
# Best mean source validation Macro-F1: 0.0585058435401033
# Checkpoint: /content/drive/MyDrive/task2/results/dann_best.pth

# %%
# %cd /content/drive/MyDrive
# !python -m task2.train --config task2/configs/cdan.yaml
# Out:
# /content/drive/MyDrive
# Device: cuda
# Method: cdan
# photo: 1336 train, 334 validation
# art_painting: 1638 train, 410 validation
# cartoon: 1875 train, 469 validation
#
# Epoch 01 | Total Loss: 0.9723 | Cls: 0.5202 | Domain: 0.4521 | Alpha: 0.0826 | Mean Source Macro-F1: 0.8639
#   photo         | Acc: 0.9222 | Macro-F1: 0.9076
#   art_painting  | Acc: 0.8220 | Macro-F1: 0.8168
#   cartoon       | Acc: 0.8635 | Macro-F1: 0.8671
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/cdan_best.pth
#
# Epoch 02 | Total Loss: 0.8984 | Cls: 0.2630 | Domain: 0.6355 | Alpha: 0.2441 | Mean Source Macro-F1: 0.9026
#   photo         | Acc: 0.9521 | Macro-F1: 0.9434
#   art_painting  | Acc: 0.8341 | Macro-F1: 0.8418
#   cartoon       | Acc: 0.9126 | Macro-F1: 0.9226
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/cdan_best.pth
#
# Epoch 03 | Total Loss: 1.1111 | Cls: 0.3466 | Domain: 0.7645 | Alpha: 0.3931 | Mean Source Macro-F1: 0.9045
#   photo         | Acc: 0.9551 | Macro-F1: 0.9487
#   art_painting  | Acc: 0.8561 | Macro-F1: 0.8590
#   cartoon       | Acc: 0.8955 | Macro-F1: 0.9056
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/cdan_best.pth
#
# Epoch 04 | Total Loss: 0.8655 | Cls: 0.1732 | Domain: 0.6922 | Alpha: 0.5240 | Mean Source Macro-F1: 0.8689
#   photo         | Acc: 0.9371 | Macro-F1: 0.9251
#   art_painting  | Acc: 0.8073 | Macro-F1: 0.8051
#   cartoon       | Acc: 0.8721 | Macro-F1: 0.8764
#
# Epoch 05 | Total Loss: 0.8431 | Cls: 0.1547 | Domain: 0.6884 | Alpha: 0.6341 | Mean Source Macro-F1: 0.9153
#   photo         | Acc: 0.9521 | Macro-F1: 0.9441
#   art_painting  | Acc: 0.8756 | Macro-F1: 0.8760
#   cartoon       | Acc: 0.9168 | Macro-F1: 0.9258
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/cdan_best.pth
#
# Epoch 06 | Total Loss: 0.8228 | Cls: 0.1325 | Domain: 0.6903 | Alpha: 0.7234 | Mean Source Macro-F1: 0.9131
#   photo         | Acc: 0.9401 | Macro-F1: 0.9289
#   art_painting  | Acc: 0.8756 | Macro-F1: 0.8728
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9376
#
# Epoch 07 | Total Loss: 0.7564 | Cls: 0.0794 | Domain: 0.6770 | Alpha: 0.7937 | Mean Source Macro-F1: 0.9115
#   photo         | Acc: 0.9371 | Macro-F1: 0.9278
#   art_painting  | Acc: 0.8780 | Macro-F1: 0.8750
#   cartoon       | Acc: 0.9254 | Macro-F1: 0.9316
#
# Epoch 08 | Total Loss: 0.7843 | Cls: 0.0946 | Domain: 0.6897 | Alpha: 0.8477 | Mean Source Macro-F1: 0.8872
#   photo         | Acc: 0.9132 | Macro-F1: 0.8977
#   art_painting  | Acc: 0.8659 | Macro-F1: 0.8518
#   cartoon       | Acc: 0.9104 | Macro-F1: 0.9121
#
# Epoch 09 | Total Loss: 0.7622 | Cls: 0.0785 | Domain: 0.6837 | Alpha: 0.8884 | Mean Source Macro-F1: 0.9188
#   photo         | Acc: 0.9641 | Macro-F1: 0.9572
#   art_painting  | Acc: 0.8585 | Macro-F1: 0.8615
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9377
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/cdan_best.pth
#
# Epoch 10 | Total Loss: 0.7916 | Cls: 0.1042 | Domain: 0.6874 | Alpha: 0.9188 | Mean Source Macro-F1: 0.9143
#   photo         | Acc: 0.9491 | Macro-F1: 0.9392
#   art_painting  | Acc: 0.8610 | Macro-F1: 0.8621
#   cartoon       | Acc: 0.9360 | Macro-F1: 0.9415
#
# Epoch 11 | Total Loss: 0.9057 | Cls: 0.1659 | Domain: 0.7398 | Alpha: 0.9411 | Mean Source Macro-F1: 0.8008
#   photo         | Acc: 0.8982 | Macro-F1: 0.8855
#   art_painting  | Acc: 0.7195 | Macro-F1: 0.6827
#   cartoon       | Acc: 0.8358 | Macro-F1: 0.8342
#
# Epoch 12 | Total Loss: 1.7271 | Cls: 1.0016 | Domain: 0.7255 | Alpha: 0.9575 | Mean Source Macro-F1: 0.0654
#   photo         | Acc: 0.2575 | Macro-F1: 0.0585
#   art_painting  | Acc: 0.2220 | Macro-F1: 0.0565
#   cartoon       | Acc: 0.1983 | Macro-F1: 0.0811
#
# Epoch 13 | Total Loss: 2.4068 | Cls: 1.7216 | Domain: 0.6853 | Alpha: 0.9693 | Mean Source Macro-F1: 0.3606
#   photo         | Acc: 0.4910 | Macro-F1: 0.3395
#   art_painting  | Acc: 0.3610 | Macro-F1: 0.2650
#   cartoon       | Acc: 0.5053 | Macro-F1: 0.4772
#
# Epoch 14 | Total Loss: 3.0036 | Cls: 2.0736 | Domain: 0.9301 | Alpha: 0.9779 | Mean Source Macro-F1: 0.0507
#   photo         | Acc: 0.2575 | Macro-F1: 0.0585
#   art_painting  | Acc: 0.2195 | Macro-F1: 0.0514
#   cartoon       | Acc: 0.1727 | Macro-F1: 0.0421
#
# Early stopping at epoch 14.
#
# Training complete.
# Best mean source validation Macro-F1: 0.9188308787099165
# Checkpoint: /content/drive/MyDrive/task2/results/cdan_best.pth

# %%
# %cd /content/drive/MyDrive
# !python -m task2.evaluate_final
# Out:
# /content/drive/MyDrive
# Device: cuda
#
# ======================================================================
# Source-only
# photo         | Acc: 0.9701 | Macro-F1: 0.9645
# art_painting  | Acc: 0.8878 | Macro-F1: 0.8870
# cartoon       | Acc: 0.9403 | Macro-F1: 0.9480
#
# Mean Source Val | Acc: 0.9327 | Macro-F1: 0.9332
# Target          | Acc: 0.5602 | Macro-F1: 0.5559
#
# ======================================================================
# DAN
# photo         | Acc: 0.9760 | Macro-F1: 0.9723
# art_painting  | Acc: 0.9073 | Macro-F1: 0.9101
# cartoon       | Acc: 0.9424 | Macro-F1: 0.9469
#
# Mean Source Val | Acc: 0.9419 | Macro-F1: 0.9431
# Target          | Acc: 0.7111 | Macro-F1: 0.6672
#
# ======================================================================
# DANN
# photo         | Acc: 0.2575 | Macro-F1: 0.0586
# art_painting  | Acc: 0.2195 | Macro-F1: 0.0518
# cartoon       | Acc: 0.1727 | Macro-F1: 0.0650
#
# Mean Source Val | Acc: 0.2166 | Macro-F1: 0.0585
# Target          | Acc: 0.0494 | Macro-F1: 0.0450
#
# ======================================================================
# CDAN
# photo         | Acc: 0.9641 | Macro-F1: 0.9572
# art_painting  | Acc: 0.8585 | Macro-F1: 0.8615
# cartoon       | Acc: 0.9318 | Macro-F1: 0.9377
#
# Mean Source Val | Acc: 0.9181 | Macro-F1: 0.9188
# Target          | Acc: 0.6427 | Macro-F1: 0.6041
# FINAL COMPARISON
# Method             Src Acc     Src F1   Target Acc    Target F1   Target ΔAcc
# Source-only         0.9327     0.9332       0.5602       0.5559       +0.0000
# DAN                 0.9419     0.9431       0.7111       0.6672       +0.1509
# DANN                0.2166     0.0585       0.0494       0.0450       -0.5108
# CDAN                0.9181     0.9188       0.6427       0.6041       +0.0825
# DOMAIN SEPARABILITY
# Source-only     | Domain Separability: 1.0000
# DAN             | Domain Separability: 0.9518
# DANN            | Domain Separability: 0.9934
# CDAN            | Domain Separability: 0.9967
# PER-CLASS TARGET ANALYSIS
#
# Source-only
#   dog       : 0.6244
#   elephant  : 0.6581
#   giraffe   : 0.2537
#   guitar    : 0.8076
#   horse     : 0.4632
#   house     : 0.4250
#   person    : 0.8625
#
# DAN
#   dog       : 0.5298
#   elephant  : 0.6838
#   giraffe   : 0.6467
#   guitar    : 0.8947
#   horse     : 0.7610
#   house     : 1.0000
#   person    : 0.9187
#
# DANN
#   dog       : 0.0622
#   elephant  : 0.0784
#   giraffe   : 0.0000
#   guitar    : 0.0148
#   horse     : 0.0000
#   house     : 0.9375
#   person    : 0.0250
#
# CDAN
#   dog       : 0.2474
#   elephant  : 0.8757
#   giraffe   : 0.4993
#   guitar    : 0.9375
#   horse     : 0.6262
#   house     : 1.0000
#   person    : 0.9313
# CLASS-SPECIFIC CHANGE RELATIVE TO SOURCE-ONLY
#
# DAN
#   Largest improvement: house (+0.5750)
#   Largest degradation: dog (-0.0946)
#   Dominant confusion for dog: person
#
# DANN
#   Largest improvement: house (+0.5125)
#   Largest degradation: person (-0.8375)
#   Dominant confusion for house: person
#   Dominant confusion for person: house
#
# CDAN
#   Largest improvement: house (+0.5750)
#   Largest degradation: dog (-0.3769)
#   Dominant confusion for dog: person
#
# Results saved to: /content/drive/MyDrive/task2/results/part5_final_results.json

# %%
# %cd /content/drive/MyDrive
# !python -m task2.train --config task2/configs/dan_lambda_0.1.yaml
# Out:
# /content/drive/MyDrive
# Device: cuda
# Method: dan
# photo: 1336 train, 334 validation
# art_painting: 1638 train, 410 validation
# cartoon: 1875 train, 469 validation
#
# Epoch 01 | Total Loss: 0.4743 | Cls: 0.4589 | MMD: 0.1543 | Mean Source Macro-F1: 0.9154
#   photo         | Acc: 0.9611 | Macro-F1: 0.9521
#   art_painting  | Acc: 0.8634 | Macro-F1: 0.8631
#   cartoon       | Acc: 0.9254 | Macro-F1: 0.9310
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_lambda_0.1_best.pth
#
# Epoch 02 | Total Loss: 0.2040 | Cls: 0.1967 | MMD: 0.0731 | Mean Source Macro-F1: 0.9093
#   photo         | Acc: 0.9551 | Macro-F1: 0.9478
#   art_painting  | Acc: 0.8634 | Macro-F1: 0.8630
#   cartoon       | Acc: 0.9083 | Macro-F1: 0.9172
#
# Epoch 03 | Total Loss: 0.1416 | Cls: 0.1359 | MMD: 0.0563 | Mean Source Macro-F1: 0.9451
#   photo         | Acc: 0.9671 | Macro-F1: 0.9613
#   art_painting  | Acc: 0.9122 | Macro-F1: 0.9115
#   cartoon       | Acc: 0.9574 | Macro-F1: 0.9626
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_lambda_0.1_best.pth
#
# Epoch 04 | Total Loss: 0.1187 | Cls: 0.1141 | MMD: 0.0459 | Mean Source Macro-F1: 0.9306
#   photo         | Acc: 0.9641 | Macro-F1: 0.9566
#   art_painting  | Acc: 0.9000 | Macro-F1: 0.9005
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9347
#
# Epoch 05 | Total Loss: 0.1011 | Cls: 0.0962 | MMD: 0.0493 | Mean Source Macro-F1: 0.9080
#   photo         | Acc: 0.9401 | Macro-F1: 0.9274
#   art_painting  | Acc: 0.8805 | Macro-F1: 0.8748
#   cartoon       | Acc: 0.9126 | Macro-F1: 0.9217
#
# Epoch 06 | Total Loss: 0.0900 | Cls: 0.0860 | MMD: 0.0397 | Mean Source Macro-F1: 0.8961
#   photo         | Acc: 0.9222 | Macro-F1: 0.9134
#   art_painting  | Acc: 0.8341 | Macro-F1: 0.8385
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9363
#
# Epoch 07 | Total Loss: 0.0948 | Cls: 0.0907 | MMD: 0.0404 | Mean Source Macro-F1: 0.9259
#   photo         | Acc: 0.9611 | Macro-F1: 0.9550
#   art_painting  | Acc: 0.8902 | Macro-F1: 0.8933
#   cartoon       | Acc: 0.9211 | Macro-F1: 0.9293
#
# Epoch 08 | Total Loss: 0.0604 | Cls: 0.0572 | MMD: 0.0324 | Mean Source Macro-F1: 0.9058
#   photo         | Acc: 0.9461 | Macro-F1: 0.9415
#   art_painting  | Acc: 0.8537 | Macro-F1: 0.8488
#   cartoon       | Acc: 0.9275 | Macro-F1: 0.9272
#
# Early stopping at epoch 8.
#
# Training complete.
# Best mean source validation Macro-F1: 0.9451386078230541
# Checkpoint: /content/drive/MyDrive/task2/results/dan_lambda_0.1_best.pth

# %%
# %cd /content/drive/MyDrive
# !python -m task2.train --config task2/configs/dan_lambda_1.yaml
# Out:
# /content/drive/MyDrive
# Device: cuda
# Method: dan
# photo: 1336 train, 334 validation
# art_painting: 1638 train, 410 validation
# cartoon: 1875 train, 469 validation
#
# Epoch 01 | Total Loss: 0.5083 | Cls: 0.4541 | MMD: 0.0541 | Mean Source Macro-F1: 0.9138
#   photo         | Acc: 0.9551 | Macro-F1: 0.9498
#   art_painting  | Acc: 0.8561 | Macro-F1: 0.8533
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9381
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_lambda_1.0_best.pth
#
# Epoch 02 | Total Loss: 0.2272 | Cls: 0.1988 | MMD: 0.0284 | Mean Source Macro-F1: 0.8966
#   photo         | Acc: 0.9461 | Macro-F1: 0.9363
#   art_painting  | Acc: 0.8707 | Macro-F1: 0.8587
#   cartoon       | Acc: 0.8934 | Macro-F1: 0.8947
#
# Epoch 03 | Total Loss: 0.1820 | Cls: 0.1591 | MMD: 0.0229 | Mean Source Macro-F1: 0.9264
#   photo         | Acc: 0.9641 | Macro-F1: 0.9563
#   art_painting  | Acc: 0.8854 | Macro-F1: 0.8865
#   cartoon       | Acc: 0.9318 | Macro-F1: 0.9364
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_lambda_1.0_best.pth
#
# Epoch 04 | Total Loss: 0.1219 | Cls: 0.1106 | MMD: 0.0113 | Mean Source Macro-F1: 0.9088
#   photo         | Acc: 0.9251 | Macro-F1: 0.9092
#   art_painting  | Acc: 0.8951 | Macro-F1: 0.8911
#   cartoon       | Acc: 0.9190 | Macro-F1: 0.9261
#
# Epoch 05 | Total Loss: 0.1098 | Cls: 0.0956 | MMD: 0.0143 | Mean Source Macro-F1: 0.9171
#   photo         | Acc: 0.9551 | Macro-F1: 0.9459
#   art_painting  | Acc: 0.8463 | Macro-F1: 0.8516
#   cartoon       | Acc: 0.9488 | Macro-F1: 0.9537
#
# Epoch 06 | Total Loss: 0.0808 | Cls: 0.0703 | MMD: 0.0105 | Mean Source Macro-F1: 0.9431
#   photo         | Acc: 0.9760 | Macro-F1: 0.9723
#   art_painting  | Acc: 0.9073 | Macro-F1: 0.9101
#   cartoon       | Acc: 0.9424 | Macro-F1: 0.9469
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_lambda_1.0_best.pth
#
# Epoch 07 | Total Loss: 0.0779 | Cls: 0.0713 | MMD: 0.0066 | Mean Source Macro-F1: 0.9189
#   photo         | Acc: 0.9641 | Macro-F1: 0.9586
#   art_painting  | Acc: 0.8561 | Macro-F1: 0.8573
#   cartoon       | Acc: 0.9403 | Macro-F1: 0.9408
#
# Epoch 08 | Total Loss: 0.0831 | Cls: 0.0745 | MMD: 0.0086 | Mean Source Macro-F1: 0.9193
#   photo         | Acc: 0.9461 | Macro-F1: 0.9369
#   art_painting  | Acc: 0.8756 | Macro-F1: 0.8837
#   cartoon       | Acc: 0.9339 | Macro-F1: 0.9374
#
# Epoch 09 | Total Loss: 0.0609 | Cls: 0.0521 | MMD: 0.0088 | Mean Source Macro-F1: 0.9100
#   photo         | Acc: 0.9491 | Macro-F1: 0.9414
#   art_painting  | Acc: 0.8634 | Macro-F1: 0.8624
#   cartoon       | Acc: 0.9190 | Macro-F1: 0.9260
#
# Epoch 10 | Total Loss: 0.0727 | Cls: 0.0666 | MMD: 0.0061 | Mean Source Macro-F1: 0.9326
#   photo         | Acc: 0.9551 | Macro-F1: 0.9467
#   art_painting  | Acc: 0.8976 | Macro-F1: 0.8980
#   cartoon       | Acc: 0.9488 | Macro-F1: 0.9531
#
# Epoch 11 | Total Loss: 0.0620 | Cls: 0.0547 | MMD: 0.0073 | Mean Source Macro-F1: 0.9223
#   photo         | Acc: 0.9581 | Macro-F1: 0.9503
#   art_painting  | Acc: 0.8756 | Macro-F1: 0.8670
#   cartoon       | Acc: 0.9467 | Macro-F1: 0.9498
#
# Early stopping at epoch 11.
#
# Training complete.
# Best mean source validation Macro-F1: 0.943114996056044
# Checkpoint: /content/drive/MyDrive/task2/results/dan_lambda_1.0_best.pth

# %%
# %cd /content/drive/MyDrive
# !python -m task2.train --config task2/configs/dan_lambda_10.yaml
# Out:
# /content/drive/MyDrive
# Device: cuda
# Method: dan
# photo: 1336 train, 334 validation
# art_painting: 1638 train, 410 validation
# cartoon: 1875 train, 469 validation
#
# Epoch 01 | Total Loss: 1.1114 | Cls: 0.7102 | MMD: 0.0401 | Mean Source Macro-F1: 0.8974
#   photo         | Acc: 0.9581 | Macro-F1: 0.9504
#   art_painting  | Acc: 0.8293 | Macro-F1: 0.8271
#   cartoon       | Acc: 0.9104 | Macro-F1: 0.9146
#   --> Best checkpoint saved: /content/drive/MyDrive/task2/results/dan_lambda_10.0_best.pth
#
# Epoch 02 | Total Loss: 0.5437 | Cls: 0.3913 | MMD: 0.0152 | Mean Source Macro-F1: 0.8841
#   photo         | Acc: 0.9341 | Macro-F1: 0.9220
#   art_painting  | Acc: 0.8366 | Macro-F1: 0.8339
#   cartoon       | Acc: 0.8955 | Macro-F1: 0.8964
#
# Epoch 03 | Total Loss: 0.4353 | Cls: 0.2900 | MMD: 0.0145 | Mean Source Macro-F1: 0.8382
#   photo         | Acc: 0.9102 | Macro-F1: 0.8992
#   art_painting  | Acc: 0.7756 | Macro-F1: 0.7775
#   cartoon       | Acc: 0.8316 | Macro-F1: 0.8379
#
# Epoch 04 | Total Loss: 0.3098 | Cls: 0.2602 | MMD: 0.0050 | Mean Source Macro-F1: 0.8876
#   photo         | Acc: 0.9401 | Macro-F1: 0.9271
#   art_painting  | Acc: 0.8512 | Macro-F1: 0.8468
#   cartoon       | Acc: 0.8891 | Macro-F1: 0.8887
#
# Epoch 05 | Total Loss: 0.4531 | Cls: 0.2843 | MMD: 0.0169 | Mean Source Macro-F1: 0.8485
#   photo         | Acc: 0.9102 | Macro-F1: 0.8994
#   art_painting  | Acc: 0.8000 | Macro-F1: 0.7891
#   cartoon       | Acc: 0.8550 | Macro-F1: 0.8569
#
# Epoch 06 | Total Loss: 0.3451 | Cls: 0.2449 | MMD: 0.0100 | Mean Source Macro-F1: 0.8339
#   photo         | Acc: 0.9222 | Macro-F1: 0.9072
#   art_painting  | Acc: 0.7829 | Macro-F1: 0.7662
#   cartoon       | Acc: 0.8316 | Macro-F1: 0.8283
#
# Early stopping at epoch 6.
#
# Training complete.
# Best mean source validation Macro-F1: 0.8973608382069237
# Checkpoint: /content/drive/MyDrive/task2/results/dan_lambda_10.0_best.pth

# %%
# %cd /content/drive/MyDrive
# !python -m task2.evaluate_sensitivity
# Out:
# /content/drive/MyDrive
#
# ================================================================================
# DAN LAMBDA SENSITIVITY STUDY
#
# DAN λ=0.1
# Source Acc: 0.9455
# Source Macro-F1: 0.9451
# Target Acc: 0.7674
# Target Macro-F1: 0.7529
# Domain Separability: 0.9884
#
# DAN λ=1
# Source Acc: 0.9419
# Source Macro-F1: 0.9431
# Target Acc: 0.7111
# Target Macro-F1: 0.6672
# Domain Separability: 0.9518
#
# DAN λ=10
# Source Acc: 0.8993
# Source Macro-F1: 0.8974
# Target Acc: 0.6396
# Target Macro-F1: 0.6039
# Domain Separability: 0.9219
#
# ================================================================================
# DAN LAMBDA SENSITIVITY RESULTS
# Setting             Src Acc      Src F1    Target Acc     Target F1   Domain Sep.
# DAN λ=0.1            0.9455      0.9451        0.7674        0.7529        0.9884
# DAN λ=1              0.9419      0.9431        0.7111        0.6672        0.9518
# DAN λ=10             0.8993      0.8974        0.6396        0.6039        0.9219
