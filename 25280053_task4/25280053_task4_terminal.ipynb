# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/task4
# Out:
# /content/drive/MyDrive/task4

# %%
# !python extract_outputs.py
# Out:
# Device: cuda
# Loaded checkpoint from epoch: 1
# Validation accuracy: 0.3938
#
# Extracting cifar10_train (45000 examples)...
# Features: (45000, 512)
# Logits: (45000, 10)
#
# Extracting cifar10_val (5000 examples)...
# Features: (5000, 512)
# Logits: (5000, 10)
#
# Extracting cifar10_test (10000 examples)...
# Features: (10000, 512)
# Logits: (10000, 10)
#
# Extracting cifar100_near (800 examples)...
# Features: (800, 512)
# Logits: (800, 10)
#
# Extracting cifar100_far (800 examples)...
# Features: (800, 512)
# Logits: (800, 10)
#
# Output extraction complete.

# %%
# !python evaluate_osr.py
# Out:
# CIFAR-10 Test Accuracy: 0.4154
#
# Calculating MSP...
# Calculating MLS...
# Calculating Energy...
# Fitting Mahalanobis statistics from CIFAR-10 training features...
#
# ...
# PART 1 + PART 2 COMPLETE
# CIFAR-10 test accuracy: 0.4154
#
# Saved novelty scores:
#   msp
#   mls
#   energy
#   mahalanobis
#
# All scores use the same frozen Vanilla checkpoint outputs.

# %%
# !python evaluation/train_gcsc.py
# Out:
# Device: cuda
# Training samples: 45000
# Validation samples: 5000
# Epoch [001/100] Loss: 2.2218 Train Acc: 0.1968 Val Acc: 0.3506
#   Saved best checkpoint: /content/drive/MyDrive/task4/cache/gcsc_best.pt
# Epoch [002/100] Loss: 1.6777 Train Acc: 0.3768 Val Acc: 0.4796
#   Saved best checkpoint: /content/drive/MyDrive/task4/cache/gcsc_best.pt
# Epoch [003/100] Loss: 1.3860 Train Acc: 0.5020 Val Acc: 0.5688
#   Saved best checkpoint: /content/drive/MyDrive/task4/cache/gcsc_best.pt
# Epoch [004/100] Loss: 1.1821 Train Acc: 0.5799 Val Acc: 0.6112
#   Saved best checkpoint: /content/drive/MyDrive/task4/cache/gcsc_best.pt
# Epoch [005/100] Loss: 1.0211 Train Acc: 0.6399 Val Acc: 0.6316
#   Saved best checkpoint: /content/drive/MyDrive/task4/cache/gcsc_best.pt
# Epoch [006/100] Loss: 0.8995 Train Acc: 0.6837 Val Acc: 0.7334
#   Saved best checkpoint: /content/drive/MyDrive/task4/cache/gcsc_best.pt
# Epoch [007/100] Loss: 0.8024 Train Acc: 0.7197 Val Acc: 0.7258
# ...

# %%
# !python evaluation/evaluate_gcsc.py
# Out:
# Loaded GCSC checkpoint from epoch: 99
# Validation accuracy: 0.9566
#
# GCSC CIFAR-10 test accuracy: 0.9540
# Saved GCSC outputs to: /content/drive/MyDrive/task4/cache/gcsc

# %%
# !python evaluation/train_proser.py
# Out:
# Device: cuda
# Training samples: 45000
# Validation samples: 5000
# Loaded Vanilla checkpoint:
# Vanilla validation accuracy: 0.3938
# Initialized PROSER with Vanilla checkpoint.
# Known classifiers: 10
# Dummy classifiers: 5
# Epoch [001/50] Loss: 1.8727 CE: 1.8405 CP: 0.0292 DP: 0.0301 Val Acc: 0.4204
#   Saved best PROSER checkpoint.
# Epoch [002/50] Loss: 1.5287 CE: 1.5285 CP: 0.0002 DP: 0.0001 Val Acc: 0.4606
#   Saved best PROSER checkpoint.
# Epoch [003/50] Loss: 1.3990 CE: 1.3989 CP: 0.0001 DP: 0.0001 Val Acc: 0.4980
#   Saved best PROSER checkpoint.
# Epoch [004/50] Loss: 1.3133 CE: 1.3131 CP: 0.0001 DP: 0.0002 Val Acc: 0.5350
#   Saved best PROSER checkpoint.
# Epoch [005/50] Loss: 1.2393 CE: 1.2392 CP: 0.0001 DP: 0.0002 Val Acc: 0.5768
#   Saved best PROSER checkpoint.
# Epoch [006/50] Loss: 1.1755 CE: 1.1754 CP: 0.0001 DP: 0.0002 Val Acc: 0.5814
#   Saved best PROSER checkpoint.
# Epoch [007/50] Loss: 1.1116 CE: 1.1115 CP: 0.0001 DP: 0.0002 Val Acc: 0.6008
# ...

# %%
# !python evaluation/evaluate_proser.py
# Out:
# Device: cpu
# Loaded PROSER checkpoint:
# Checkpoint epoch: 46
# Checkpoint validation accuracy: 0.8082
#
# Unknown set sizes:
# Near: 800
# Far : 800
#
# Evaluating CIFAR-10 validation set...
# PROSER validation accuracy: 0.8082
#
# Evaluating CIFAR-10 test set...
# PROSER CIFAR-10 test accuracy: 0.8061
#
# Evaluating near unknowns...
# Evaluating far unknowns...
#
# ...
# MLS SCORE STATISTICS
# ...
# CIFAR-10 validation: mean=-6.5388, std=3.7551, min=-24.5114, max=0.9931
# CIFAR-10 test: mean=-6.5308, std=3.7838, min=-26.3342, max=0.7845
# CIFAR-100 near: mean=-4.7573, std=3.2602, min=-19.2970, max=0.7806
# CIFAR-100 far: mean=-2.8796, std=1.7878, min=-15.8103, max=0.5956
#
# ...
# DUMMY / PLACEHOLDER SCORE STATISTICS
# ...
# CIFAR-10 validation: mean=16.4244, std=1.7430, min=10.1982, max=25.4061
# CIFAR-10 test: mean=16.4062, std=1.7489, min=10.9658, max=23.9404
# CIFAR-100 near: mean=16.3986, std=1.7394, min=11.7880, max=23.2522
# CIFAR-100 far: mean=15.4269, std=1.6651, min=10.5729, max=21.8645
#
# ...

# %%
# %cd /content/drive/MyDrive/task4
# !python evaluation/evaluate_osr.py
# Out:
# /content/drive/MyDrive/task4
# Device: cpu
#
# Dataset sizes:
# CIFAR-10 validation: 5000
# CIFAR-10 test      : 10000
# Near unknowns      : 800
# Far unknowns       : 800
#
# ...
# VANILLA
# ...
# Loaded Vanilla checkpoint: /content/drive/MyDrive/task4/results/vanilla_best.pt
# Vanilla checkpoint validation accuracy: 0.3938
#   Extracting validation outputs...
#   Extracting test outputs...
#   Extracting near unknown outputs...
#   Extracting far unknown outputs...
#
# Computing Mahalanobis statistics from CIFAR-10 training features...
# Mahalanobis feature dimension: 512
#
# ...
# GCSC
# ...
# Loaded GCSC checkpoint: /content/drive/MyDrive/task4/cache/gcsc_best.pt
# GCSC checkpoint validation accuracy: 0.9566
#   Extracting validation outputs...
#   Extracting test outputs...
#   Extracting near unknown outputs...
#   Extracting far unknown outputs...
#
# ...
# PROSER
# ...
# Loaded PROSER checkpoint: /content/drive/MyDrive/task4/cache/proser_best.pt
# PROSER checkpoint validation accuracy: 0.8082
# ...
